# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importing the required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

# %%
# The function is defined with default parameters so that if you call it with just your data, it will construct a DataFrame with t-1 
# as X and t as y

def series_to_supervised(data, n_in = 1, n_out = 1, dropnan = True):
    n_vars = 1 if type(data) is list else data.shape[1]
    
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
            
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
        
    return agg

# %%
df = pd.read_csv("/content/drive/MyDrive/LSTM-Multivariate_pollution.csv")

# %%
df
# Out:
#                       date  pollution  dew  temp   press wnd_dir  wnd_spd  \
# 0      2010-01-02 00:00:00      129.0  -16  -4.0  1020.0      SE     1.79
# 1      2010-01-02 01:00:00      148.0  -15  -4.0  1020.0      SE     2.68
# 2      2010-01-02 02:00:00      159.0  -11  -5.0  1021.0      SE     3.57
# 3      2010-01-02 03:00:00      181.0   -7  -5.0  1022.0      SE     5.36
# 4      2010-01-02 04:00:00      138.0   -7  -5.0  1022.0      SE     6.25
# ...                    ...        ...  ...   ...     ...     ...      ...
# 43795  2014-12-31 19:00:00        8.0  -23  -2.0  1034.0      NW   231.97
# 43796  2014-12-31 20:00:00       10.0  -22  -3.0  1034.0      NW   237.78
# 43797  2014-12-31 21:00:00       10.0  -22  -3.0  1034.0      NW   242.70
# 43798  2014-12-31 22:00:00        8.0  -22  -4.0  1034.0      NW   246.72
# 43799  2014-12-31 23:00:00       12.0  -21  -3.0  1034.0      NW   249.85
#
#        snow  rain
# 0         0     0
# 1         0     0
# 2         0     0
# 3         1     0
# 4         2     0
# ...     ...   ...
# 43795     0     0
# 43796     0     0
# 43797     0     0
# 43798     0     0
# 43799     0     0
#
# [43800 rows x 9 columns]

# %%
df["wnd_dir"].unique()
# Out:
# array(['SE', 'cv', 'NW', 'NE'], dtype=object)

# %%
# Encoding the string based data feature into integers

def func(s):
    if s == "SE":
        return 1
    elif s == "NE":
        return 2
    elif s == "NW":
        return 3
    else:
        return 4

df["wind_dir"] = df["wnd_dir"].apply(func)

# %%
del df["wnd_dir"]

# %%
df
# Out:
#                       date  pollution  dew  temp   press  wnd_spd  snow  rain  \
# 0      2010-01-02 00:00:00      129.0  -16  -4.0  1020.0     1.79     0     0
# 1      2010-01-02 01:00:00      148.0  -15  -4.0  1020.0     2.68     0     0
# 2      2010-01-02 02:00:00      159.0  -11  -5.0  1021.0     3.57     0     0
# 3      2010-01-02 03:00:00      181.0   -7  -5.0  1022.0     5.36     1     0
# 4      2010-01-02 04:00:00      138.0   -7  -5.0  1022.0     6.25     2     0
# ...                    ...        ...  ...   ...     ...      ...   ...   ...
# 43795  2014-12-31 19:00:00        8.0  -23  -2.0  1034.0   231.97     0     0
# 43796  2014-12-31 20:00:00       10.0  -22  -3.0  1034.0   237.78     0     0
# 43797  2014-12-31 21:00:00       10.0  -22  -3.0  1034.0   242.70     0     0
# 43798  2014-12-31 22:00:00        8.0  -22  -4.0  1034.0   246.72     0     0
# 43799  2014-12-31 23:00:00       12.0  -21  -3.0  1034.0   249.85     0     0
#
#        wind_dir
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 43795         3
# 43796         3
# 43797         3
# 43798         3
# 43799         3
#
# [43800 rows x 9 columns]

# %%
values = df.values

# specify columns to plot
groups = [1, 2, 3, 4 , 5, 6, 7]
i = 1

# plot each column
plt.figure(figsize=(20,14))
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group], c = "forestgreen")
    plt.title(df.columns[group], y=0.75, loc='right', fontsize = 15)
    i += 1
plt.show()

# %%
fig = plt.figure(figsize = (20,7))
plt.plot(df.pollution)
plt.title("Polution variation across the given no.of hours", fontsize = 15)
plt.show()

# %%
del df["date"]

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %%
# Scaling the entire dataset

dataset = df
values = dataset.values

values = values.astype('float32')

scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
# converting the dataset as supervised learning

reframed = series_to_supervised(scaled, 1, 1)
print(reframed.shape)
# Out:
# (43799, 16)

# %%
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.129779   0.352941   0.245902   0.527273   0.002290   0.000000
# 2   0.148893   0.367647   0.245902   0.527273   0.003811   0.000000
# 3   0.159960   0.426471   0.229508   0.545454   0.005332   0.000000
# 4   0.182093   0.485294   0.229508   0.563637   0.008391   0.037037
# 5   0.138833   0.485294   0.229508   0.563637   0.009912   0.074074
#
#    var7(t-1)  var8(t-1)   var1(t)   var2(t)   var3(t)   var4(t)   var5(t)  \
# 1        0.0        0.0  0.148893  0.367647  0.245902  0.527273  0.003811
# 2        0.0        0.0  0.159960  0.426471  0.229508  0.545454  0.005332
# 3        0.0        0.0  0.182093  0.485294  0.229508  0.563637  0.008391
# 4        0.0        0.0  0.138833  0.485294  0.229508  0.563637  0.009912
# 5        0.0        0.0  0.109658  0.485294  0.213115  0.563637  0.011433
#
#     var6(t)  var7(t)  var8(t)
# 1  0.000000      0.0      0.0
# 2  0.000000      0.0      0.0
# 3  0.037037      0.0      0.0
# 4  0.074074      0.0      0.0
# 5  0.111111      0.0      0.0

# %%
reframed.columns
# Out:
# Index(['var1(t-1)', 'var2(t-1)', 'var3(t-1)', 'var4(t-1)', 'var5(t-1)',
#        'var6(t-1)', 'var7(t-1)', 'var8(t-1)', 'var1(t)', 'var2(t)', 'var3(t)',
#        'var4(t)', 'var5(t)', 'var6(t)', 'var7(t)', 'var8(t)'],
#       dtype='object')

# %%
# droping columns we don't want to predict

reframed.drop(reframed.columns[[9,10,11,12,13,14,15]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.129779   0.352941   0.245902   0.527273   0.002290   0.000000
# 2   0.148893   0.367647   0.245902   0.527273   0.003811   0.000000
# 3   0.159960   0.426471   0.229508   0.545454   0.005332   0.000000
# 4   0.182093   0.485294   0.229508   0.563637   0.008391   0.037037
# 5   0.138833   0.485294   0.229508   0.563637   0.009912   0.074074
#
#    var7(t-1)  var8(t-1)   var1(t)
# 1        0.0        0.0  0.148893
# 2        0.0        0.0  0.159960
# 3        0.0        0.0  0.182093
# 4        0.0        0.0  0.138833
# 5        0.0        0.0  0.109658

# %%
values = reframed.values

# We train the model on the 1st 3 years and then test on the last year (for now)
n_train_hours = 365 * 24 * 3

train = values[:n_train_hours, :]#value ko split lite tae pone san , trian & test so pee.
test = values[n_train_hours:, :]#value ko split lite tae pone san , trian & test so pee.

# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# reshape input to be 3D :- (no.of samples, no.of timesteps, no.of features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (26280, 1, 8) (26280,) (17519, 1, 8) (17519,)

# %%
train.shape, test.shape, values.shape
# Out:
# ((26280, 9), (17519, 9), (43799, 9))

# %%
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add(LSTM(64, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')

# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_split=0.2, verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 292/292 - 15s - loss: 0.0050 - val_loss: 0.0029 - 15s/epoch - 51ms/step
# Epoch 2/50
# 292/292 - 2s - loss: 0.0015 - val_loss: 0.0014 - 2s/epoch - 6ms/step
# Epoch 3/50
# 292/292 - 2s - loss: 9.5997e-04 - val_loss: 7.6590e-04 - 2s/epoch - 5ms/step
# Epoch 4/50
# 292/292 - 2s - loss: 8.6732e-04 - val_loss: 6.3480e-04 - 2s/epoch - 5ms/step
# Epoch 5/50
# 292/292 - 2s - loss: 8.4729e-04 - val_loss: 6.0876e-04 - 2s/epoch - 6ms/step
# Epoch 6/50
# 292/292 - 2s - loss: 8.4226e-04 - val_loss: 6.0237e-04 - 2s/epoch - 6ms/step
# Epoch 7/50
# 292/292 - 2s - loss: 8.4029e-04 - val_loss: 5.9631e-04 - 2s/epoch - 5ms/step
# Epoch 8/50
# 292/292 - 2s - loss: 8.3917e-04 - val_loss: 5.9060e-04 - 2s/epoch - 5ms/step
# Epoch 9/50
# 292/292 - 1s - loss: 8.3901e-04 - val_loss: 5.8619e-04 - 1s/epoch - 4ms/step
# Epoch 10/50
# 292/292 - 1s - loss: 8.3937e-04 - val_loss: 5.8166e-04 - 1s/epoch - 3ms/step
# Epoch 11/50
# 292/292 - 1s - loss: 8.3962e-04 - val_loss: 5.7695e-04 - 1s/epoch - 3ms/step
# Epoch 12/50
# 292/292 - 1s - loss: 8.3962e-04 - val_loss: 5.7286e-04 - 1s/epoch - 4ms/step
# Epoch 13/50
# 292/292 - 1s - loss: 8.3935e-04 - val_loss: 5.6972e-04 - 1s/epoch - 4ms/step
# Epoch 14/50
# 292/292 - 1s - loss: 8.3882e-04 - val_loss: 5.6748e-04 - 1s/epoch - 5ms/step
# Epoch 15/50
# 292/292 - 1s - loss: 8.3805e-04 - val_loss: 5.6595e-04 - 1s/epoch - 4ms/step
# Epoch 16/50
# 292/292 - 1s - loss: 8.3713e-04 - val_loss: 5.6496e-04 - 1s/epoch - 4ms/step
# Epoch 17/50
# 292/292 - 1s - loss: 8.3611e-04 - val_loss: 5.6437e-04 - 1s/epoch - 5ms/step
# Epoch 18/50
# 292/292 - 2s - loss: 8.3506e-04 - val_loss: 5.6408e-04 - 2s/epoch - 5ms/step
# Epoch 19/50
# 292/292 - 2s - loss: 8.3400e-04 - val_loss: 5.6401e-04 - 2s/epoch - 6ms/step
# Epoch 20/50
# 292/292 - 2s - loss: 8.3296e-04 - val_loss: 5.6409e-04 - 2s/epoch - 6ms/step
# Epoch 21/50
# 292/292 - 2s - loss: 8.3197e-04 - val_loss: 5.6428e-04 - 2s/epoch - 7ms/step
# Epoch 22/50
# 292/292 - 2s - loss: 8.3101e-04 - val_loss: 5.6455e-04 - 2s/epoch - 7ms/step
# Epoch 23/50
# 292/292 - 2s - loss: 8.3010e-04 - val_loss: 5.6486e-04 - 2s/epoch - 6ms/step
# Epoch 24/50
# 292/292 - 2s - loss: 8.2922e-04 - val_loss: 5.6520e-04 - 2s/epoch - 6ms/step
# Epoch 25/50
# 292/292 - 2s - loss: 8.2839e-04 - val_loss: 5.6555e-04 - 2s/epoch - 6ms/step
# Epoch 26/50
# 292/292 - 2s - loss: 8.2759e-04 - val_loss: 5.6590e-04 - 2s/epoch - 6ms/step
# Epoch 27/50
# 292/292 - 2s - loss: 8.2683e-04 - val_loss: 5.6625e-04 - 2s/epoch - 6ms/step
# Epoch 28/50
# 292/292 - 2s - loss: 8.2609e-04 - val_loss: 5.6659e-04 - 2s/epoch - 6ms/step
# Epoch 29/50
# 292/292 - 1s - loss: 8.2538e-04 - val_loss: 5.6693e-04 - 1s/epoch - 5ms/step
# Epoch 30/50
# 292/292 - 2s - loss: 8.2470e-04 - val_loss: 5.6724e-04 - 2s/epoch - 5ms/step
# Epoch 31/50
# 292/292 - 1s - loss: 8.2404e-04 - val_loss: 5.6755e-04 - 1s/epoch - 4ms/step
# Epoch 32/50
# 292/292 - 2s - loss: 8.2340e-04 - val_loss: 5.6784e-04 - 2s/epoch - 5ms/step
# Epoch 33/50
# 292/292 - 2s - loss: 8.2277e-04 - val_loss: 5.6813e-04 - 2s/epoch - 5ms/step
# Epoch 34/50
# 292/292 - 2s - loss: 8.2217e-04 - val_loss: 5.6840e-04 - 2s/epoch - 6ms/step
# Epoch 35/50
# 292/292 - 2s - loss: 8.2158e-04 - val_loss: 5.6866e-04 - 2s/epoch - 6ms/step
# Epoch 36/50
# 292/292 - 1s - loss: 8.2100e-04 - val_loss: 5.6891e-04 - 1s/epoch - 5ms/step
# Epoch 37/50
# 292/292 - 2s - loss: 8.2043e-04 - val_loss: 5.6917e-04 - 2s/epoch - 6ms/step
# Epoch 38/50
# 292/292 - 2s - loss: 8.1988e-04 - val_loss: 5.6944e-04 - 2s/epoch - 6ms/step
# Epoch 39/50
# 292/292 - 1s - loss: 8.1935e-04 - val_loss: 5.6967e-04 - 1s/epoch - 5ms/step
# Epoch 40/50
# 292/292 - 2s - loss: 8.1882e-04 - val_loss: 5.6983e-04 - 2s/epoch - 6ms/step
# Epoch 41/50
# 292/292 - 2s - loss: 8.1831e-04 - val_loss: 5.7001e-04 - 2s/epoch - 6ms/step
# Epoch 42/50
# 292/292 - 2s - loss: 8.1780e-04 - val_loss: 5.7022e-04 - 2s/epoch - 6ms/step
# Epoch 43/50
# 292/292 - 1s - loss: 8.1729e-04 - val_loss: 5.7036e-04 - 1s/epoch - 5ms/step
# Epoch 44/50
# 292/292 - 1s - loss: 8.1680e-04 - val_loss: 5.7051e-04 - 1s/epoch - 5ms/step
# Epoch 45/50
# 292/292 - 1s - loss: 8.1632e-04 - val_loss: 5.7075e-04 - 1s/epoch - 5ms/step
# Epoch 46/50
# 292/292 - 1s - loss: 8.1584e-04 - val_loss: 5.7093e-04 - 1s/epoch - 4ms/step
# Epoch 47/50
# 292/292 - 1s - loss: 8.1537e-04 - val_loss: 5.7108e-04 - 1s/epoch - 4ms/step
# Epoch 48/50
# 292/292 - 1s - loss: 8.1490e-04 - val_loss: 5.7122e-04 - 903ms/epoch - 3ms/step
# Epoch 49/50
# 292/292 - 1s - loss: 8.1445e-04 - val_loss: 5.7134e-04 - 811ms/epoch - 3ms/step
# Epoch 50/50
# 292/292 - 1s - loss: 8.1401e-04 - val_loss: 5.7141e-04 - 817ms/epoch - 3ms/step

# %%
plt.figure(figsize=(15,6))
plt.plot(history.history['loss'], label='train', linewidth = 2.5)
plt.plot(history.history['val_loss'], label='validation',  linewidth = 2.5)
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
test_X.shape
# Out:
# (17519, 1, 8)

# %%
testPredict = model.predict(test_X)
print(testPredict.shape)
testPredict = testPredict.ravel()

print(testPredict.shape)
# Out:
# (17519, 1)
# (17519,)

# %%
test.shape
# Out:
# (17519, 9)

# %%
print(test), print(test.shape)
# Out:
# [[0.03521127 0.44117647 0.22950819 ... 0.         0.6666666  0.03118712]
#  [0.03118712 0.4264706  0.1967213  ... 0.         0.6666666  0.03219316]
#  [0.03219316 0.4264706  0.1967213  ... 0.         0.6666666  0.02112676]
#  ...
#  [0.01006036 0.2647059  0.26229507 ... 0.         0.6666666  0.01006036]
#  [0.01006036 0.2647059  0.26229507 ... 0.         0.6666666  0.00804829]
#  [0.00804829 0.2647059  0.24590163 ... 0.         0.6666666  0.01207243]]
# (17519, 9)
# (None, None)

# %%
y_test_true = test[:,8]

# %%
y_test_true
# Out:
# array([0.03118712, 0.03219316, 0.02112676, ..., 0.01006036, 0.00804829,
#        0.01207243], dtype=float32)

# %%
poll = np.array(df["pollution"])

meanop = poll.mean()
stdop = poll.std()

y_test_true = y_test_true*stdop + meanop
testPredict = testPredict*stdop + meanop

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(15,6))
plt.xlim([1000,1250])
plt.ylabel("ppm")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "g", alpha = 0.90,label='Actual', linewidth = 2.5)
plt.plot(testPredict, c = "b", alpha = 0.75,label='Predict')
plt.title("Testing(Validation) data")
plt.legend()
plt.show()

# testTrue = scaler.inverse_transform([testY]).ravel()

# %%
rmse = np.sqrt(mean_squared_error(y_test_true, testPredict))
mae=mean_absolute_error(y_test_true,testPredict)

print("Test(Validation) RMSE ="  ,rmse)
print("Training MAE =", mae)

# As we see the,  RMSE for testing data is low, and visually as well, from the above plots, we can see that the basic model is able to
# predict the future values of pollution (in ppm) pretty well
# Out:
# Test(Validation) RMSE = 2.5796366
# Training MAE = 1.4184535

# %%
model2 = Sequential()
model2.add(LSTM(256, input_shape=(train_X.shape[1], train_X.shape[2])))
model2.add(Dense(64))
model2.add(Dropout(0.25))
model2.add(BatchNormalization())
model2.add(Dense(1))

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 256)               271360
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dropout (Dropout)           (None, 64)                0
#
#  batch_normalization (BatchN  (None, 64)               256
#  ormalization)
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 288,129
# Trainable params: 288,001
# Non-trainable params: 128
# _________________________________________________________________

# %%
model2.compile(loss='mse', optimizer='adam')

hist2 = model2.fit(train_X, train_y, epochs=50, batch_size=128, validation_data=(test_X, test_y))
# Out:
# Epoch 1/50
# 206/206 [==============================] - 3s 8ms/step - loss: 0.0118 - val_loss: 0.0079
# Epoch 2/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0016 - val_loss: 0.0058
# Epoch 3/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 4/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0014 - val_loss: 9.4816e-04
# Epoch 5/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 6/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 7/50
# 206/206 [==============================] - 1s 7ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 8/50
# 206/206 [==============================] - 2s 8ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 9/50
# 206/206 [==============================] - 2s 9ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 10/50
# 206/206 [==============================] - 2s 11ms/step - loss: 0.0012 - val_loss: 9.7765e-04
# Epoch 11/50
# 206/206 [==============================] - 2s 11ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 12/50
# 206/206 [==============================] - 2s 9ms/step - loss: 0.0011 - val_loss: 7.8684e-04
# Epoch 13/50
# 206/206 [==============================] - 2s 10ms/step - loss: 0.0011 - val_loss: 8.2188e-04
# Epoch 14/50
# 206/206 [==============================] - 2s 8ms/step - loss: 0.0011 - val_loss: 7.3132e-04
# Epoch 15/50
# 206/206 [==============================] - 2s 12ms/step - loss: 0.0010 - val_loss: 9.9393e-04
# Epoch 16/50
# 206/206 [==============================] - 2s 11ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 17/50
# 206/206 [==============================] - 2s 9ms/step - loss: 9.6762e-04 - val_loss: 8.0011e-04
# Epoch 18/50
# 206/206 [==============================] - 2s 8ms/step - loss: 9.8156e-04 - val_loss: 8.1849e-04
# Epoch 19/50
# 206/206 [==============================] - 1s 6ms/step - loss: 9.7349e-04 - val_loss: 7.3601e-04
# Epoch 20/50
# 206/206 [==============================] - 1s 6ms/step - loss: 9.5713e-04 - val_loss: 0.0012
# Epoch 21/50
# 206/206 [==============================] - 1s 7ms/step - loss: 9.6409e-04 - val_loss: 7.3213e-04
# Epoch 22/50
# 206/206 [==============================] - 1s 7ms/step - loss: 9.1232e-04 - val_loss: 0.0018
# Epoch 23/50
# 206/206 [==============================] - 1s 6ms/step - loss: 9.2611e-04 - val_loss: 8.6042e-04
# Epoch 24/50
# 206/206 [==============================] - 1s 7ms/step - loss: 9.1207e-04 - val_loss: 7.1911e-04
# Epoch 25/50
# 206/206 [==============================] - 1s 7ms/step - loss: 9.3063e-04 - val_loss: 7.2293e-04
# Epoch 26/50
# 206/206 [==============================] - 1s 7ms/step - loss: 9.3561e-04 - val_loss: 7.4034e-04
# Epoch 27/50
# 206/206 [==============================] - 2s 10ms/step - loss: 9.1776e-04 - val_loss: 7.1405e-04
# Epoch 28/50
# 206/206 [==============================] - 2s 11ms/step - loss: 9.3245e-04 - val_loss: 7.9938e-04
# Epoch 29/50
# 206/206 [==============================] - 2s 11ms/step - loss: 9.0891e-04 - val_loss: 0.0010
# Epoch 30/50
# 206/206 [==============================] - 3s 13ms/step - loss: 9.0465e-04 - val_loss: 0.0011
# Epoch 31/50
# 206/206 [==============================] - 2s 11ms/step - loss: 9.5033e-04 - val_loss: 8.5911e-04
# Epoch 32/50
# 206/206 [==============================] - 2s 11ms/step - loss: 9.4280e-04 - val_loss: 8.7462e-04
# Epoch 33/50
# 206/206 [==============================] - 2s 10ms/step - loss: 9.0811e-04 - val_loss: 9.0672e-04
# Epoch 34/50
# 206/206 [==============================] - 2s 11ms/step - loss: 9.2061e-04 - val_loss: 7.7336e-04
# Epoch 35/50
# 206/206 [==============================] - 2s 10ms/step - loss: 9.0132e-04 - val_loss: 8.0589e-04
# Epoch 36/50
# 206/206 [==============================] - 2s 10ms/step - loss: 9.0963e-04 - val_loss: 7.2831e-04
# Epoch 37/50
# 206/206 [==============================] - 2s 7ms/step - loss: 9.1976e-04 - val_loss: 8.0801e-04
# Epoch 38/50
# 206/206 [==============================] - 2s 10ms/step - loss: 9.2004e-04 - val_loss: 8.6251e-04
# Epoch 39/50
# 206/206 [==============================] - 3s 16ms/step - loss: 9.2504e-04 - val_loss: 8.0667e-04
# Epoch 40/50
# 206/206 [==============================] - 1s 6ms/step - loss: 9.0320e-04 - val_loss: 8.7402e-04
# Epoch 41/50
# 206/206 [==============================] - 1s 7ms/step - loss: 9.0823e-04 - val_loss: 8.0231e-04
# Epoch 42/50
# 206/206 [==============================] - 1s 6ms/step - loss: 9.2399e-04 - val_loss: 8.1832e-04
# Epoch 43/50
# 206/206 [==============================] - 1s 6ms/step - loss: 9.2287e-04 - val_loss: 7.9566e-04
# Epoch 44/50
# 206/206 [==============================] - 1s 6ms/step - loss: 9.2892e-04 - val_loss: 7.4118e-04
# Epoch 45/50
# 206/206 [==============================] - 1s 6ms/step - loss: 9.4170e-04 - val_loss: 0.0013
# Epoch 46/50
# 206/206 [==============================] - 2s 8ms/step - loss: 9.0973e-04 - val_loss: 7.5229e-04
# Epoch 47/50
# 206/206 [==============================] - 2s 10ms/step - loss: 9.2400e-04 - val_loss: 9.0776e-04
# Epoch 48/50
# 206/206 [==============================] - 2s 12ms/step - loss: 9.3789e-04 - val_loss: 9.2412e-04
# Epoch 49/50
# 206/206 [==============================] - 2s 9ms/step - loss: 9.4587e-04 - val_loss: 7.5926e-04
# Epoch 50/50
# 206/206 [==============================] - 2s 12ms/step - loss: 9.1317e-04 - val_loss: 8.4241e-04

# %%
plt.figure(figsize=(15,6))
plt.plot(hist2.history['loss'], label='train', linewidth = 2.5)
plt.plot(hist2.history['val_loss'], label='validation',  linewidth = 2.5)
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
y_test_true = test[:,8]

# %%
testPredict2 = model2.predict(test_X)
testPredict2 = testPredict2.ravel()

# Inverse scaling the output, for better visual interpretation 

poll = np.array(df["pollution"])
meanop = poll.mean()
stdop = poll.std()

print(meanop, stdop)

y_test_true = y_test_true*stdop + meanop
testPredict2 = testPredict2*stdop + meanop
# Out:
# 94.01351598173515 92.25122315439845

# %%
y_test_true
# Out:
# array([96.89057 , 96.983376, 95.96249 , ..., 94.9416  , 94.75598 ,
#        95.12721 ], dtype=float32)

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(15,6))
plt.xlim([1000,1250])
plt.ylabel("ppm")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "green", alpha = 0.95,label='Actual',linewidth = 2.5)
plt.plot(testPredict2, c = "darkblue", alpha = 0.75,label='Predict')
plt.title("Testing(Validation) data")
plt.legend()
plt.show()

# %%
rmse = np.sqrt(mean_squared_error(y_test_true, testPredict2))
mae=mean_absolute_error(y_test_true,testPredict2)
print("Training MAE =", mae)
print("Test(Validation) RMSE ="  ,rmse)
# Out:
# Training MAE = 1.685976
# Test(Validation) RMSE = 2.6775215

# %%
values.shape
# Out:
# (43799, 9)

# %%
values
# Out:
# array([[0.12977867, 0.35294122, 0.24590163, ..., 0.        , 0.        ,
#         0.14889336],
#        [0.14889336, 0.36764708, 0.24590163, ..., 0.        , 0.        ,
#         0.15995975],
#        [0.15995975, 0.4264706 , 0.22950819, ..., 0.        , 0.        ,
#         0.18209255],
#        ...,
#        [0.01006036, 0.2647059 , 0.26229507, ..., 0.        , 0.6666666 ,
#         0.01006036],
#        [0.01006036, 0.2647059 , 0.26229507, ..., 0.        , 0.6666666 ,
#         0.00804829],
#        [0.00804829, 0.2647059 , 0.24590163, ..., 0.        , 0.6666666 ,
#         0.01207243]], dtype=float32)

# %%
train_x, train_y = values[:, :-1], values[:, -1]
print(train_x.shape, train_y.shape)
# Out:
# (43799, 8) (43799,)

# %%
train_x = train_x.reshape((train_x.shape[0], 1, train_x.shape[1]))

# %%
model3 = Sequential()
model3.add(LSTM(256, input_shape=(train_x.shape[1], train_x.shape[2])))
model3.add(Dense(32))
model3.add(Dropout(0.25))
model3.add(BatchNormalization())
model3.add(Dense(1))

model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 256)               271360
#
#  dense_3 (Dense)             (None, 32)                8224
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  batch_normalization_1 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 279,745
# Trainable params: 279,681
# Non-trainable params: 64
# _________________________________________________________________

# %%
model3.compile(loss='mse', optimizer='adam')

hist3 = model3.fit(train_x, train_y, epochs=50, batch_size=256, validation_split=0.2)
# Out:
# Epoch 1/50
# 137/137 [==============================] - 4s 9ms/step - loss: 0.0170 - val_loss: 0.0079
# Epoch 2/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0014 - val_loss: 0.0071
# Epoch 3/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0012 - val_loss: 0.0054
# Epoch 4/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0012 - val_loss: 0.0030
# Epoch 5/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 6/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 7/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0013 - val_loss: 7.0490e-04
# Epoch 8/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0013 - val_loss: 7.8102e-04
# Epoch 9/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0013 - val_loss: 6.2165e-04
# Epoch 10/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0013 - val_loss: 7.7888e-04
# Epoch 11/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0013 - val_loss: 0.0044
# Epoch 12/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0012 - val_loss: 9.5651e-04
# Epoch 13/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0012 - val_loss: 6.6811e-04
# Epoch 14/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0012 - val_loss: 7.2929e-04
# Epoch 15/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 16/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0012 - val_loss: 7.2934e-04
# Epoch 17/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0012 - val_loss: 7.9391e-04
# Epoch 18/50
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0012 - val_loss: 9.0467e-04
# Epoch 19/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0011 - val_loss: 6.5466e-04
# Epoch 20/50
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0011 - val_loss: 8.8333e-04
# Epoch 21/50
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 22/50
# 137/137 [==============================] - 1s 10ms/step - loss: 0.0011 - val_loss: 6.9715e-04
# Epoch 23/50
# 137/137 [==============================] - 1s 10ms/step - loss: 0.0011 - val_loss: 9.8061e-04
# Epoch 24/50
# 137/137 [==============================] - 1s 8ms/step - loss: 0.0011 - val_loss: 9.8927e-04
# Epoch 25/50
# 137/137 [==============================] - 1s 9ms/step - loss: 0.0011 - val_loss: 6.2449e-04
# Epoch 26/50
# 137/137 [==============================] - 1s 9ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 27/50
# 137/137 [==============================] - 1s 10ms/step - loss: 0.0010 - val_loss: 6.4620e-04
# Epoch 28/50
# 137/137 [==============================] - 2s 12ms/step - loss: 0.0010 - val_loss: 6.5891e-04
# Epoch 29/50
# 137/137 [==============================] - 1s 9ms/step - loss: 9.7607e-04 - val_loss: 6.6962e-04
# Epoch 30/50
# 137/137 [==============================] - 1s 9ms/step - loss: 9.9105e-04 - val_loss: 8.5962e-04
# Epoch 31/50
# 137/137 [==============================] - 2s 11ms/step - loss: 9.7536e-04 - val_loss: 5.9107e-04
# Epoch 32/50
# 137/137 [==============================] - 1s 9ms/step - loss: 9.8539e-04 - val_loss: 7.2959e-04
# Epoch 33/50
# 137/137 [==============================] - 1s 8ms/step - loss: 9.8551e-04 - val_loss: 6.4020e-04
# Epoch 34/50
# 137/137 [==============================] - 1s 8ms/step - loss: 9.8220e-04 - val_loss: 7.0717e-04
# Epoch 35/50
# 137/137 [==============================] - 1s 7ms/step - loss: 9.8508e-04 - val_loss: 8.1439e-04
# Epoch 36/50
# 137/137 [==============================] - 1s 6ms/step - loss: 9.8689e-04 - val_loss: 6.1604e-04
# Epoch 37/50
# 137/137 [==============================] - 1s 6ms/step - loss: 9.3900e-04 - val_loss: 6.3825e-04
# Epoch 38/50
# 137/137 [==============================] - 1s 6ms/step - loss: 9.4106e-04 - val_loss: 6.0637e-04
# Epoch 39/50
# 137/137 [==============================] - 1s 6ms/step - loss: 9.4095e-04 - val_loss: 8.1627e-04
# Epoch 40/50
# 137/137 [==============================] - 1s 6ms/step - loss: 9.3472e-04 - val_loss: 6.0128e-04
# Epoch 41/50
# 137/137 [==============================] - 1s 6ms/step - loss: 9.3865e-04 - val_loss: 7.5972e-04
# Epoch 42/50
# 137/137 [==============================] - 1s 6ms/step - loss: 9.1769e-04 - val_loss: 6.1369e-04
# Epoch 43/50
# 137/137 [==============================] - 1s 6ms/step - loss: 9.3295e-04 - val_loss: 6.1166e-04
# Epoch 44/50
# 137/137 [==============================] - 1s 6ms/step - loss: 9.3221e-04 - val_loss: 6.7188e-04
# Epoch 45/50
# 137/137 [==============================] - 1s 6ms/step - loss: 9.3878e-04 - val_loss: 5.9912e-04
# Epoch 46/50
# 137/137 [==============================] - 1s 6ms/step - loss: 9.5183e-04 - val_loss: 7.7492e-04
# Epoch 47/50
# 137/137 [==============================] - 1s 7ms/step - loss: 9.4732e-04 - val_loss: 6.4578e-04
# Epoch 48/50
# 137/137 [==============================] - 1s 6ms/step - loss: 9.1367e-04 - val_loss: 6.2228e-04
# Epoch 49/50
# 137/137 [==============================] - 1s 6ms/step - loss: 9.0927e-04 - val_loss: 6.3657e-04
# Epoch 50/50
# 137/137 [==============================] - 1s 6ms/step - loss: 9.1464e-04 - val_loss: 6.6189e-04

# %%
plt.figure(figsize=(15,6))
plt.plot(hist3.history['loss'], label='train', linewidth = 2.5)
plt.plot(hist3.history['val_loss'], label='validation',  linewidth = 2.5)
plt.legend()
plt.show()

# %%
y_test_true = test[:,8]

# %%
testPredict3= model3.predict(test_X)
testPredict3 = testPredict3.ravel()

# Inverse scaling the output, for better visual interpretation 

poll = np.array(df["pollution"])
meanop = poll.mean()
stdop = poll.std()

print(meanop, stdop)

y_test_true = y_test_true*stdop + meanop
testPredict3 = testPredict3*stdop + meanop
# Out:
# 94.01351598173515 92.25122315439845

# %%
testPredict3
# Out:
# array([96.622574, 96.26948 , 96.35472 , ..., 93.98027 , 93.97957 ,
#        93.81118 ], dtype=float32)

# %%
y_test_true
# Out:
# array([96.89057 , 96.983376, 95.96249 , ..., 94.9416  , 94.75598 ,
#        95.12721 ], dtype=float32)

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(15,6))
plt.xlim([1000,1250])
plt.ylabel("ppm")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "green", alpha = 0.95,label='Actual',linewidth = 2.5)
plt.plot(testPredict3, c = "darkblue", alpha = 0.75,label='Predict')
plt.title("Testing(Validation) data")
plt.legend()
plt.show()

# %%
rmse = np.sqrt(mean_squared_error(y_test_true, testPredict3))
mae=mean_absolute_error(y_test_true,testPredict2)
print("Training MAE =", mae)
print("Test(Validation) RMSE ="  ,rmse)
# Out:
# Training MAE = 1.685976
# Test(Validation) RMSE = 2.5564046

# %%
y_train_true = values[:,8]

# %%
trainPredict3 = model3.predict(train_x)
trainPredict3 = trainPredict3.ravel()

# Inverse scaling the output, for better visual interpretation 

poll = np.array(df["pollution"])
meanop = poll.mean()
stdop = poll.std()

print(meanop, stdop)

y_train_true = y_train_true*stdop + meanop
trainPredict3 = trainPredict3*stdop + meanop
# Out:
# 94.01351598173515 92.25122315439845

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
# plt.xlim([1000,1250])
plt.ylabel("ppm")
plt.xlabel("hrs")
plt.plot(y_train_true, c = "cyan", alpha = 0.90, linewidth = 2.5)
plt.plot(trainPredict3, c = "darkblue", alpha = 0.75)
plt.title("Training data")
plt.show()
